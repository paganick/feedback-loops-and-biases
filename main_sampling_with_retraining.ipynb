# %%
import os
import warnings
import tikzplotlib
import numpy as np

warnings.filterwarnings("ignore", category=RuntimeWarning) 
warnings.simplefilter('ignore', category=FutureWarning)
from input_parameters import input_parameters
from model import model

np.random.seed(0)
results_folder = 'results/sampling_with_retraining/'

if not os.path.exists(results_folder):
    os.makedirs(results_folder)
input_parameters = input_parameters(feedback_loop_type = 'Sampling', retraining = True, results_folder = results_folder)

Model = model(input_parameters)
t = 0
g1x_0, g1y_0, g2x_0, g2y_0, px_0, py_0 = Model.plot_ML_model(t)

# %%
n0_0, n1_0 = Model.population.plot_hist_group(t)
theta0_vector0, theta1_vector0 = Model.population.plot_hist_theta(t)
# Out:
# No handles with labels found to put in legend.

# %%
n_t = 2000 
t = t+n_t
Model.run(T=n_t)
n0_1, n1_1 = Model.population.plot_hist_group(t)
theta0_vector1, theta1_vector1 = Model.population.plot_hist_theta(t)
# Out:
# No handles with labels found to put in legend.

# %%
n_t = 8000 
t = t+n_t
Model.run(T=n_t)
n0_2, n1_2 = Model.population.plot_hist_group(t)
theta0_vector2, theta1_vector2 = Model.population.plot_hist_theta(t)
# Out:
# No handles with labels found to put in legend.

# %%
n_t = 10000 
t = t+n_t
Model.run(T=n_t)
n0_3, n1_3 = Model.population.plot_hist_group(t)
theta0_vector3, theta1_vector3 = Model.population.plot_hist_theta(t)
# Out:
# No handles with labels found to put in legend.

# %%
n_t = 30000 
t = t+n_t
Model.run(T=n_t)
n0_4, n1_4 = Model.population.plot_hist_group(t)
theta0_vector4, theta1_vector4 = Model.population.plot_hist_theta(t)
# Out:
# No handles with labels found to put in legend.

# %%
import matplotlib.pyplot as plt
import numpy as np


data_0 = [theta0_vector0, theta0_vector1, theta0_vector2, theta0_vector3, theta0_vector4]
data_1 = [theta1_vector0, theta1_vector1, theta1_vector2, theta1_vector3, theta1_vector4]

ticks = ['0', '2000', '10000', '20000', '50000']

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)
    plt.setp(bp['fliers'], color=color)

plt.figure()


flierprops = dict(markeredgecolor='#D7191C')

bpl = plt.boxplot(data_0, positions=np.array(range(len(data_0)))*2.0-0.4, widths=0.6, flierprops=flierprops)
flierprops = dict(markeredgecolor='#2C7BB6')
bpr = plt.boxplot(data_1, positions=np.array(range(len(data_1)))*2.0+0.4, widths=0.6, flierprops=flierprops)
set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#2C7BB6')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#D7191C', label='Group 1')
plt.plot([], c='#2C7BB6', label='Group 2')
plt.legend()

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlabel('time-steps')
plt.ylabel('theta')
plt.tight_layout()
tikzplotlib.save(results_folder+'thetas.tikz')

# %%
import matplotlib.pyplot as plt
import numpy as np


data_0 = [theta0_vector0, theta0_vector1, theta0_vector2, theta0_vector3, theta0_vector4]
data_1 = [theta1_vector0, theta1_vector1, theta1_vector2, theta1_vector3, theta1_vector4]

ticks = ['0', '2000', '10000', '20000', '50000']

def set_box_color(bp, color):
    plt.setp(bp['bodies'], color=color)
    plt.setp(bp['cmaxes'], color=color)
    plt.setp(bp['cmins'], color=color)
    plt.setp(bp['cbars'], color=color)

plt.figure()

bpl = plt.violinplot(data_0, positions=np.array(range(len(data_0)))*2.0-0.4, widths=0.6)
bpr = plt.violinplot(data_1, positions=np.array(range(len(data_1)))*2.0+0.4, widths=0.6)
set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#2C7BB6')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#D7191C', label='Group 1')
plt.plot([], c='#2C7BB6', label='Group 2')
plt.legend()

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlabel('time-steps')
plt.ylabel('theta')
plt.tight_layout()
tikzplotlib.save(results_folder+'thetas_violin.tikz')

# %%
colors=['red', 'blue']
names=['Group 1', 'Group 2']
x0 = [n0_0, n0_1, n0_2, n0_3, n0_4]
x1 = [n1_0, n1_1, n1_2, n1_3, n1_4]

X_axis = np.arange(len(x0))
  
plt.bar(X_axis - 0.2, x0, 0.4, label = 'Group 1', color='#D7191C')
plt.bar(X_axis + 0.2, x1, 0.4, label = 'Group 2', color='#2C7BB6')

ticks = ['0', '2000', '10000', '20000', '50000']
plt.xticks(range(0, len(ticks), 1), ticks)
plt.xlabel('time-steps')
plt.ylabel('Number of users')
plt.legend()
tikzplotlib.save(results_folder+'number_of_users.tikz')

# %%
g1x_0, g1y_0, g2x_0, g2y_0, px_1, py_1 = Model.plot_ML_model(t)
